# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
NCurves = 10
y = np.zeros((NCurves,256))

for i in range(NCurves):
    coeffs = np.random.rand(4)-0.5
    p = np.polynomial.Polynomial(coeffs)
    x,y[i,:] = p.linspace(256, [0,1])
    

plt.plot(x,np.transpose(y))
